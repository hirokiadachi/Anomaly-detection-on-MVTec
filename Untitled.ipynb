# %%
# %run -i evaluation.py --gpu 0 --model_path ./checkpoint/grid/model --data_root /root/datasets/mvtec_anomaly_detection --category grid
# Out:
# Augmentation: 100%|██████████| 10000/10000 [03:15<00:00, 51.17it/s]
# train data size : 10000
# img_dir : /root/datasets/mvtec_anomaly_detection/grid/test
# gt_dir  : /root/datasets/mvtec_anomaly_detection/grid/ground_truth
# img_types : ['bent', 'broken', 'glue', 'good', 'metal_contamination', 'thread']
# Textures category
# test dataset size :  78
# Start to record reconstruction loss and DSSIM score for calculating threshold.
# 100%|██████████| 10000/10000 [00:34<00:00, 286.91it/s]
# train loss size : 10000
# train ssim size : 10000
# ----- start Anomaly detection -----------
# Reconstruction threshold:  9267.5576171875
# Classification threshold : 0.0005503408271726462
# Quantile 0: 78it [01:12,  1.07it/s]
# auroc_score : 0.5108735213107667
#
# Reconstruction threshold:  10063.28935546875
# Classification threshold : 0.010060598727169922
# Quantile 10: 78it [01:04,  1.20it/s]
# auroc_score : 0.7092374818827918
#
# Reconstruction threshold:  10189.962890625
# ...

# %%
# %run -i train.py --data_root /root/datasets/mvtec_anomaly_detection --category grid --gpu 0 --epochs 20000
# Out:
# Get training dataset.
# Augmentation: 100%|██████████| 10000/10000 [04:06<00:00, 40.54it/s]
# train data size : 10000
# Build training network.
# 0 epoch [0/1000] | loss: 373023.8750 | rec loss: 372899.8750 | KL: 123.9874
# 0 epoch [100/1000] | loss: 133083.9375 | rec loss: 129484.6172 | KL: 3599.3157
# 0 epoch [200/1000] | loss: 124091.7969 | rec loss: 122385.1094 | KL: 1706.6840
# 0 epoch [300/1000] | loss: 124173.6328 | rec loss: 123394.5469 | KL: 779.0869
# 0 epoch [400/1000] | loss: 122046.3984 | rec loss: 121386.1172 | KL: 660.2812
# 0 epoch [500/1000] | loss: 119376.9453 | rec loss: 118657.2188 | KL: 719.7249
# 0 epoch [600/1000] | loss: 118498.5469 | rec loss: 118172.6875 | KL: 325.8589
# 0 epoch [700/1000] | loss: 113835.3281 | rec loss: 113506.7109 | KL: 328.6146
# 0 epoch [800/1000] | loss: 114395.2500 | rec loss: 114305.8906 | KL: 89.3563
# 0 epoch [900/1000] | loss: 112396.1641 | rec loss: 112306.9922 | KL: 89.1729
# ...

# %%
import numpy as np
np.percentile(np.arange(100), 50)
# Out:
# 49.5
